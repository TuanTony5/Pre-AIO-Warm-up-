# %% [markdown]
# # Tabular data

# %%
import pandas as pd 

data = pd.read_csv("Pandas_data/advertising_simple.csv")
data
# Out:
#     TV  Radio  Newspaper  Sales
# 0   44     39         45     10
# 1   17     45         69     12
# 2  151     41         58     16
# 3  180     10         58     17
# 4    8     48         75      7
# 5   57     32         23     11
# 6  120     19         11     13
# 7    8      2          1      4

# %% [markdown]
# # Time-series data

# %%
import pandas as pd 

df = pd.read_csv("Pandas_data/weatherHistory_univariate.csv")
df
# Out:
#                       Formatted Date  Temperature (C)
# 0      2006-04-01 00:00:00.000 +0200         9.472222
# 1      2006-04-01 01:00:00.000 +0200         9.355556
# 2      2006-04-01 02:00:00.000 +0200         9.377778
# 3      2006-04-01 03:00:00.000 +0200         8.288889
# 4      2006-04-01 04:00:00.000 +0200         8.755556
# ...                              ...              ...
# 96448  2016-09-09 19:00:00.000 +0200        26.016667
# 96449  2016-09-09 20:00:00.000 +0200        24.583333
# 96450  2016-09-09 21:00:00.000 +0200        22.038889
# 96451  2016-09-09 22:00:00.000 +0200        21.522222
# 96452  2016-09-09 23:00:00.000 +0200        20.438889
#
# [96453 rows x 2 columns]

# %%
# Sort data by date columns
df = df.sort_values('Formatted Date')
df.head()
# Out:
#                      Formatted Date  Temperature (C)
# 2880  2006-01-01 00:00:00.000 +0100         0.577778
# 2881  2006-01-01 01:00:00.000 +0100         1.161111
# 2882  2006-01-01 02:00:00.000 +0100         1.666667
# 2883  2006-01-01 03:00:00.000 +0100         1.711111
# 2884  2006-01-01 04:00:00.000 +0100         1.183333

# %%
# Convert to datetime object
df['Formatted Date'] = [pd.to_datetime(time) for time in df['Formatted Date']]
df.head()
# Out:
#                  Formatted Date  Temperature (C)
# 2880  2006-01-01 00:00:00+01:00         0.577778
# 2881  2006-01-01 01:00:00+01:00         1.161111
# 2882  2006-01-01 02:00:00+01:00         1.666667
# 2883  2006-01-01 03:00:00+01:00         1.711111
# 2884  2006-01-01 04:00:00+01:00         1.183333

# %%
df['date'] = [time.date() for time in df['Formatted Date']]
df.head()
# Out:
#                  Formatted Date  Temperature (C)        date
# 2880  2006-01-01 00:00:00+01:00         0.577778  2006-01-01
# 2881  2006-01-01 01:00:00+01:00         1.161111  2006-01-01
# 2882  2006-01-01 02:00:00+01:00         1.666667  2006-01-01
# 2883  2006-01-01 03:00:00+01:00         1.711111  2006-01-01
# 2884  2006-01-01 04:00:00+01:00         1.183333  2006-01-01

# %%
df['day'] = [time.day for time in df['Formatted Date']]
df.head()
# Out:
#                  Formatted Date  Temperature (C)        date  day
# 2880  2006-01-01 00:00:00+01:00         0.577778  2006-01-01    1
# 2881  2006-01-01 01:00:00+01:00         1.161111  2006-01-01    1
# 2882  2006-01-01 02:00:00+01:00         1.666667  2006-01-01    1
# 2883  2006-01-01 03:00:00+01:00         1.711111  2006-01-01    1
# 2884  2006-01-01 04:00:00+01:00         1.183333  2006-01-01    1

# %%
df['timestamp'] = [time.timestamp() for time in df['Formatted Date']]
df.head()
# Out:
#                  Formatted Date  Temperature (C)        date  day  \
# 2880  2006-01-01 00:00:00+01:00         0.577778  2006-01-01    1
# 2881  2006-01-01 01:00:00+01:00         1.161111  2006-01-01    1
# 2882  2006-01-01 02:00:00+01:00         1.666667  2006-01-01    1
# 2883  2006-01-01 03:00:00+01:00         1.711111  2006-01-01    1
# 2884  2006-01-01 04:00:00+01:00         1.183333  2006-01-01    1
#
#          timestamp
# 2880  1.136070e+09
# 2881  1.136074e+09
# 2882  1.136077e+09
# 2883  1.136081e+09
# 2884  1.136084e+09

# %% [markdown]
# # Text data

# %%
import pandas as pd 

df = pd.read_csv("Pandas_data/train.csv")
df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
dff = df.rename(columns={'text':'tweet'})
dff.head()
# Out:
#    id keyword location                                              tweet  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df_shuffle = df.sample(frac=1,random_state=44)

# %%
df_shuffle.drop(['id'],axis=1,inplace=True)
df_shuffle.head()
# Out:
#                   keyword             location  \
# 67               accident               CLVLND
# 1209  buildings%20burning  GO BLUE! HAIL YES!!
# 944            blown%20up                  ATX
# 3711                 fear                  NaN
# 5825               rubble                   ON
#
#                                                    text  target
# 67    'I can't have kids cuz I got in a bicycle acci...       0
# 1209  @1acd4900c1424d1 @FoxNews no one is rioting bu...       1
# 944   @luke_winkie Whoever is directing these videos...       0
# 3711  The Opposite of Love is Fear HereÛªs Why\nhtt...       1
# 5825  China's Stock Market Crash: Are There Gems In ...       1

# %%
df_shuffle.reset_index(inplace=True,drop=True)
df_shuffle.head()
# Out:
#                keyword             location  \
# 0             accident               CLVLND
# 1  buildings%20burning  GO BLUE! HAIL YES!!
# 2           blown%20up                  ATX
# 3                 fear                  NaN
# 4               rubble                   ON
#
#                                                 text  target
# 0  'I can't have kids cuz I got in a bicycle acci...       0
# 1  @1acd4900c1424d1 @FoxNews no one is rioting bu...       1
# 2  @luke_winkie Whoever is directing these videos...       0
# 3  The Opposite of Love is Fear HereÛªs Why\nhtt...       1
# 4  China's Stock Market Crash: Are There Gems In ...       1

# %%
df_shuffle.target.value_counts()
# Out:
# target
# 0    4342
# 1    3271
# Name: count, dtype: int64

# %%
num = df_shuffle['text'].to_numpy()
num
# Out:
# array(["'I can't have kids cuz I got in a bicycle accident &amp; split my testicles. it's impossible for me to have kids' MICHAEL YOU ARE THE FATHER",
#        '@1acd4900c1424d1 @FoxNews no one is rioting burning down buildings or looting.',
#        '@luke_winkie Whoever is directing these videos needs to grab up Nicki Minaj or someone with U.S. recognition so minds can be blown.',
#        ..., '@Hollyorange8 my day has been a disaster of emotions',
#        '#cum explosion!\n\n@begforcum \n@allday_cumshots \n@cumcovered \n@sexycumshots \n@Cumtown\n@BJ_Nutt\n@cumslut_2\n@GirlsLoveCum http://t.co/2CX1yjjoZ9',
#        '@VillicanaAlicia [[Is it Darude Sandstorm?]]'], dtype=object)

# %%
print(type(num))
# Out:
# <class 'numpy.ndarray'>
